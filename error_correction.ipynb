# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
# %matplotlib inline

# %%
IMG_ROOT = 'D:\Codes\mask_recognition\data/train'
data=pd.read_csv(r'D:\Codes\mask_recognition\xml_df')
data
# Out:
#      Unnamed: 0                                           filename  width  \
# 0             0  -1x-1_jpg.rf.69d9b61e3cdb8a9047dad25099fcc8ef.jpg   2000
# 1             1  -1x-1_jpg.rf.69d9b61e3cdb8a9047dad25099fcc8ef.jpg   2000
# 2             2  -1x-1_jpg.rf.69d9b61e3cdb8a9047dad25099fcc8ef.jpg   2000
# 3             3  -1x-1_jpg.rf.69d9b61e3cdb8a9047dad25099fcc8ef.jpg   2000
# 4             4  -1x-1_jpg.rf.69d9b61e3cdb8a9047dad25099fcc8ef.jpg   2000
# ..          ...                                                ...    ...
# 691         691  w1240-p16x9-6f1db5e0460631cfa98d2d6d8032942f81...   1240
# 692         692  w1240-p16x9-6f1db5e0460631cfa98d2d6d8032942f81...   1240
# 693         693  w1240-p16x9-6f1db5e0460631cfa98d2d6d8032942f81...   1240
# 694         694  w1240-p16x9-6f1db5e0460631cfa98d2d6d8032942f81...   1240
# 695         695  W37H3GWNO5EV5HTJQNP4KLIRGI_jpg.rf.71c3c2741aa5...   1000
#
#      height    class  xmin  xmax  ymin  ymax
# ...

# %%
# Get image as numpy array
def load_image(name, path):
    img_path = path +'/'+ name + '.jpg'
    # img = cv2.imread(img_path)
    img = mpimg.imread(img_path)
    return img

# Plot numpy array
def plot_image(img):
    plt.imshow(img)
    
    plt.title(img.shape)
    
# Plot a grid of examples
def plot_grid(img_names, img_root, rows=5, cols=5):
    fig = plt.figure(figsize=(25,25))
    
    for i,name in enumerate(img_names):
        fig.add_subplot(rows,cols,i+1)
        img = load_image(name, img_root)
        plot_image(img)
        
    plt.show()

# %%
plot_grid(data['filename'][:25], IMG_ROOT)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5532/1079917372.py in <module>
# ----> 1 plot_grid(data['filename'][:25], IMG_ROOT)
#
# ~\AppData\Local\Temp/ipykernel_5532/2748050894.py in plot_grid(img_names, img_root, rows, cols)
#      18     for i,name in enumerate(img_names):
#      19         fig.add_subplot(rows,cols,i+1)
# ---> 20         img = load_image(name, img_root)
#      21         plot_image(img)
#      22
#
# ~\AppData\Local\Temp/ipykernel_5532/2748050894.py in load_image(name, path)
#       3     img_path = path +'/'+ name + '.jpg'
#       4     # img = cv2.imread(img_path)
# ----> 5     img = mpimg.imread(img_path)
#       6     return img
#       7
#
# ~\anaconda3\envs\object\lib\site-packages\matplotlib\image.py in imread(fname, format)
#    1558                     response = io.BytesIO(response.read())
# ...

# %%
len(data.filename.unique())
# Out:
# 105
